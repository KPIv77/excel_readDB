# %%
# Check column names in the table
import sqlite3
import pandas as pd

conn = sqlite3.connect(f"/home/kph/project/excel_readDB/file_read/iris_data.db")

query = """
SELECT * FROM table

"""

df = pd.read_sql(query, conn)
df.columns.tolist()

# %%
# Query data from the table
import sqlite3
import pandas as pd


# path SQL
conn = sqlite3.connect(f"path file.db")


# Table Data
query = """

SELECT column1, column2, column3

FROM [table]
WHERE [column name] = 'value'
"""
result = pd.read_sql(query, conn)
result

# %%
# Close the connection
conn.close()
